# %% [markdown]
# # Prediccion de Precio de Vehiculos

# %%
# Importacion de librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importacion del archivo csv
df = pd.read_csv("../../Archivos-Analisis/vehicle_price_prediction.csv")
df
# Out:
#                  make       model  year  mileage  engine_hp transmission  \
# 0          Volkswagen       Jetta  2016   183903        173       Manual
# 1               Lexus          RX  2010   236643        352       Manual
# 2              Subaru   Crosstrek  2016   103199        188    Automatic
# 3            Cadillac       Lyriq  2016   118889        338       Manual
# 4              Toyota  Highlander  2018   204170        196       Manual
# ...               ...         ...   ...      ...        ...          ...
# 999995           Jeep    Cherokee  2015   130407        176       Manual
# 999996          Dodge  Challenger  2013   276316        211       Manual
# 999997  Mercedes-Benz     E-Class  2023     3964        339    Automatic
# 999998          Volvo        XC90  2019    83674        311    Automatic
# 999999            Ram        1500  2022    44863        240    Automatic
#
#        fuel_type drivetrain     body_type exterior_color interior_color  \
# ...

# %%
# Deteccion de nulos en las columnas
df.isnull().sum()
# Out:
# make                     0
# model                    0
# year                     0
# mileage                  0
# engine_hp                0
# transmission             0
# fuel_type                0
# drivetrain               0
# body_type                0
# exterior_color           0
# interior_color           0
# owner_count              0
# accident_history    750133
# seller_type              0
# condition                0
# trim                     0
# vehicle_age              0
# mileage_per_year         0
# brand_popularity         0
# price                    0
# dtype: int64

# %%
# Analisis de la columna
df['accident_history']
# Out:
# 0           NaN
# 1         Minor
# 2           NaN
# 3           NaN
# 4         Minor
#           ...
# 999995      NaN
# 999996    Minor
# 999997      NaN
# 999998      NaN
# 999999      NaN
# Name: accident_history, Length: 1000000, dtype: object

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   make              1000000 non-null  object
#  1   model             1000000 non-null  object
#  2   year              1000000 non-null  int64
#  3   mileage           1000000 non-null  int64
#  4   engine_hp         1000000 non-null  int64
#  5   transmission      1000000 non-null  object
#  6   fuel_type         1000000 non-null  object
#  7   drivetrain        1000000 non-null  object
#  8   body_type         1000000 non-null  object
#  9   exterior_color    1000000 non-null  object
#  10  interior_color    1000000 non-null  object
#  11  owner_count       1000000 non-null  int64
#  12  accident_history  249867 non-null   object
#  13  seller_type       1000000 non-null  object
#  14  condition         1000000 non-null  object
# ...

# %%
# Eliminacion de columnas que no aportan a la prediccion
df = df.drop(columns=["accident_history", "exterior_color", "interior_color"])
df
# Out:
#                  make       model  year  mileage  engine_hp transmission  \
# 0          Volkswagen       Jetta  2016   183903        173       Manual
# 1               Lexus          RX  2010   236643        352       Manual
# 2              Subaru   Crosstrek  2016   103199        188    Automatic
# 3            Cadillac       Lyriq  2016   118889        338       Manual
# 4              Toyota  Highlander  2018   204170        196       Manual
# ...               ...         ...   ...      ...        ...          ...
# 999995           Jeep    Cherokee  2015   130407        176       Manual
# 999996          Dodge  Challenger  2013   276316        211       Manual
# 999997  Mercedes-Benz     E-Class  2023     3964        339    Automatic
# 999998          Volvo        XC90  2019    83674        311    Automatic
# 999999            Ram        1500  2022    44863        240    Automatic
#
#        fuel_type drivetrain     body_type  owner_count seller_type  condition  \
# ...

# %%
# Usamos get_dummies para convertir las columnas categoricas en numericas
df = pd.get_dummies(df, drop_first=True)

# %%
# Separamos variables predictoras y objetivo
x = df.drop("price", axis=1)
y = df["price"]

# %%
# Dividir en entrenamiento y prueba
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Entrenar modelo de regresion
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Evaluar el modelo
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = model.predict(x_test)
print("MAE:", mean_absolute_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
# Out:
# MAE: 2450.2583050512762
# R2: 0.9295281627030153
