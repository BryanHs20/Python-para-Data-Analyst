# %% [markdown]
# # Proyecto Empresa aliada

# %% [markdown]
# ## Importacion de las librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importacion de los archivos

# %% [markdown]
# ### SALES

# %%
df_sales = pd.read_csv("FACT_SALES.csv")
df_sales
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_sales = pd.read_csv("FACT_SALES.csv")
#       2 df_sales
#
# File c:\Users\RyanHz\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# ### PRODUCT

# %%
df_product = pd.read_excel("PRODUCT.xlsx")
df_product
# Out:
#     MANUFACTURER     BRAND              ITEM  \
# 0     INDS. ALEN  CLORALEX          75000592
# 1     INDS. ALEN  CLORALEX          75000608
# 2     INDS. ALEN  CLORALEX          75000615
# 3     INDS. ALEN  CLORALEX          75000622
# 4     INDS. ALEN  CLORALEX          75000639
# ..           ...       ...               ...
# 500      RECKITT    VANISH  7501058789778BP1
# 501   INDS. ALEN  CLORALEX     7501025412142
# 502   INDS. ALEN  CLORALEX               NaN
# 503       CLOROX    CLOROX               NaN
# 504       CLOROX    CLOROX  7502240948188BP1
#
#                                       ITEM_DESCRIPTION  CATEGORY   FORMAT  \
# 0    CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 000...         1  LIQUIDO
# 1    CLORALEX EL RENDIDOR BOT.PLAST. 500ML NAL. 000...         1  LIQUIDO
# 2    CLORALEX EL RENDIDOR BOT.PLAST. 950ML NAL. 000...         1  LIQUIDO
# 3    CLORALEX EL RENDIDOR BOT.PLAST. 2000ML NAL 000...         1  LIQUIDO
# ...

# %% [markdown]
# ### CALENDAR

# %%
df_calendar = pd.read_excel("CALENDAR.xlsx")
df_calendar
# Out:
#       WEEK  YEAR  MONTH  WEEK_NUMBER       DATE
# 0    01-21  2021      1            1 2021-01-10
# 1    02-21  2021      1            2 2021-01-17
# 2    03-21  2021      1            3 2021-01-24
# 3    04-21  2021      1            4 2021-01-31
# 4    05-21  2021      2            5 2021-02-07
# ..     ...   ...    ...          ...        ...
# 151  48-23  2023     12           48 2023-12-04
# 152  49-23  2023     12           49 2023-12-11
# 153  50-23  2023     12           50 2023-12-18
# 154  51-23  2023     12           51 2023-12-25
# 155  52-23  2023      1           52 2024-01-01
#
# [156 rows x 5 columns]

# %% [markdown]
# ### SEGMENT

# %%
df_segment = pd.read_excel("SEGMENT.xlsx")
df_segment.head(20)
# Out:
#     CATEGORY       ATTR1             ATTR2        ATTR3   FORMAT       SEGMENT
# 0          1       CLORO             CLORO      BAMBINO  LIQUIDO        BLEACH
# 1          1       CLORO             CLORO    GERMICIDA  LIQUIDO        BLEACH
# 2          1       CLORO             CLORO     MASCOTAS  LIQUIDO        BLEACH
# 3          1       CLORO             CLORO    MULTIUSOS      GEL        BLEACH
# 4          1       CLORO             CLORO    MULTIUSOS  LIQUIDO        BLEACH
# 5          1       CLORO             CLORO  NO DEFINIDO  LIQUIDO        BLEACH
# 6          1       CLORO             CLORO  NO DEFINIDO    POLVO        BLEACH
# 7          1       CLORO             CLORO   OTR. TIPOS  LIQUIDO        BLEACH
# 8          1       CLORO             CLORO   OTR. TIPOS    POLVO        BLEACH
# 9          1       CLORO             CLORO    ROPA BEBE  LIQUIDO        BLEACH
# 10         1       CLORO             CLORO          NaN  LIQUIDO        BLEACH
# ...

# %% [markdown]
# ### CATEGORY

# %%
df_category = pd.read_csv("CATEGORY.csv")
df_category
# Out:
#    ID_CATEGORY                        CATEGORY
# 0            1  FABRIC TREATMENT and SANIT\r\n
# 1            2                       AIR CARE
# 2            3                    LAVAVAJILLAS
# 3            4                MEGA SUPERFICIES
# 4            5             LAVATORY CARE & BRC

# %% [markdown]
# ## Revisión y comprensión de los csv/xlsx:
# Comenzando con este punto, quiera comentar cual es la función que emplean los archivos Excel proporcionados, ya que es importante conocer sus diferencias y sus funciones que emplean en conjunto.
# Para facilitar la comprensión, no se nombraran como el nombre que tienen el doc, sino de una forma más práctica:
#
# - Categoría (DIM_CATEGORY): Tabla catálogo, cuenta con 5 registros junto con sus 5 identificadores “Id’s”.
# - Producto (DIM_PRODUCT): Tabla general de todos los productos que maneja la empresa, esto involucra manufactureros, marcas y descripciones. Se relaciona con la Tabla Categoría (category) y Segmento (format).
# - Segmento (DIM_SEGMENT): Tabla que maneja los segmentos del mercado básicos. Se relaciona con la tabla Categoría (category).
# - Calendario (DIM_CALENDAR): Tabla catalogo que maneja de las fechas por semana desde el año 2021 al 2023.
# - Ventas (FACT_SALES): Tabla principal de las ventas totales de los años 2022 al 2023. Se relaciona con Producto (item) y Calendario (week).

# %% [markdown]
# ### Informacion de cada tabla

# %% [markdown]
# #### SALES

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122002 entries, 0 to 122001
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   WEEK                         109722 non-null  object
#  1   ITEM_CODE                    122002 non-null  object
#  2   TOTAL_UNIT_SALES             122002 non-null  float64
#  3   TOTAL_VALUE_SALES            122002 non-null  float64
#  4   TOTAL_UNIT_AVG_WEEKLY_SALES  122002 non-null  float64
#  5   REGION                       122002 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 5.6+ MB

# %% [markdown]
# #### PRODUCT

# %%
df_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MANUFACTURER      505 non-null    object
#  1   BRAND             505 non-null    object
#  2   ITEM              503 non-null    object
#  3   ITEM_DESCRIPTION  505 non-null    object
#  4   CATEGORY          505 non-null    int64
#  5   FORMAT            505 non-null    object
#  6   ATTR1             499 non-null    object
#  7   ATTR2             505 non-null    object
#  8   ATTR3             499 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 35.6+ KB

# %% [markdown]
# #### CATEGORY

# %%
df_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID_CATEGORY  5 non-null      int64
#  1   CATEGORY     5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes

# %% [markdown]
# #### SEGMENT

# %%
df_segment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CATEGORY  53 non-null     int64
#  1   ATTR1     53 non-null     object
#  2   ATTR2     53 non-null     object
#  3   ATTR3     52 non-null     object
#  4   FORMAT    53 non-null     object
#  5   SEGMENT   53 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.6+ KB

# %% [markdown]
# #### CALENDAR

# %%
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   WEEK         156 non-null    object
#  1   YEAR         156 non-null    int64
#  2   MONTH        156 non-null    int64
#  3   WEEK_NUMBER  156 non-null    int64
#  4   DATE         156 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 6.2+ KB

# %% [markdown]
# ## Normalizacion de Columnas
# Se ajustaran los nombres de las columnas de las siguientes tablas:
#
# - SEGMENT: CETEGORY pasa a ID_CATEGORY
# - PRODUCT: CETEGORY pasa a ID_CATEGORY
# - SALES: ITEM_CODE pasa a ITEM

# %% [markdown]
# ### Ajuste SEGMENT

# %%
df_segment.rename(columns = {"CATEGORY": "ID_CATEGORY"}, inplace = True)
df_segment
# Out:
#     ID_CATEGORY        ATTR1             ATTR2                ATTR3   FORMAT  \
# 0             1        CLORO             CLORO              BAMBINO  LIQUIDO
# 1             1        CLORO             CLORO            GERMICIDA  LIQUIDO
# 2             1        CLORO             CLORO             MASCOTAS  LIQUIDO
# 3             1        CLORO             CLORO            MULTIUSOS      GEL
# 4             1        CLORO             CLORO            MULTIUSOS  LIQUIDO
# 5             1        CLORO             CLORO          NO DEFINIDO  LIQUIDO
# 6             1        CLORO             CLORO          NO DEFINIDO    POLVO
# 7             1        CLORO             CLORO           OTR. TIPOS  LIQUIDO
# 8             1        CLORO             CLORO           OTR. TIPOS    POLVO
# 9             1        CLORO             CLORO            ROPA BEBE  LIQUIDO
# 10            1        CLORO             CLORO                  NaN  LIQUIDO
# ...

# %% [markdown]
# ### Ajuste PRODUCT

# %%
df_product.rename(columns = {"CATEGORY": "ID_CATEGORY"}, inplace = True)
df_product
# Out:
#     MANUFACTURER     BRAND              ITEM  \
# 0     INDS. ALEN  CLORALEX          75000592
# 1     INDS. ALEN  CLORALEX          75000608
# 2     INDS. ALEN  CLORALEX          75000615
# 3     INDS. ALEN  CLORALEX          75000622
# 4     INDS. ALEN  CLORALEX          75000639
# ..           ...       ...               ...
# 500      RECKITT    VANISH  7501058789778BP1
# 501   INDS. ALEN  CLORALEX     7501025412142
# 502   INDS. ALEN  CLORALEX               NaN
# 503       CLOROX    CLOROX               NaN
# 504       CLOROX    CLOROX  7502240948188BP1
#
#                                       ITEM_DESCRIPTION  ID_CATEGORY   FORMAT  \
# 0    CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 000...            1  LIQUIDO
# 1    CLORALEX EL RENDIDOR BOT.PLAST. 500ML NAL. 000...            1  LIQUIDO
# 2    CLORALEX EL RENDIDOR BOT.PLAST. 950ML NAL. 000...            1  LIQUIDO
# 3    CLORALEX EL RENDIDOR BOT.PLAST. 2000ML NAL 000...            1  LIQUIDO
# ...

# %% [markdown]
# ### Ajuste SALES

# %%
df_sales.rename(columns = {"ITEM_CODE": "ITEM"}, inplace = True)
df_sales
# Out:
#          WEEK              ITEM  TOTAL_UNIT_SALES  TOTAL_VALUE_SALES  \
# 0       34-22  7501058792808BP2             0.006              0.139
# 1       34-22     7501060000000             0.487            116.519
# 2       34-22     7702630000000             1.391             68.453
# 3       34-22     7501060000000             0.022              1.481
# 4       34-22     7501060000000             2.037            182.839
# ...       ...               ...               ...                ...
# 121997  26-23  7501058792778BP1             1.192            150.829
# 121998  26-23     7501060000000             1.947            235.416
# 121999  26-23     7501060000000            18.013            429.289
# 122000  26-23  7702626204208BP1            21.152            210.276
# 122001  26-23     7501060000000             1.468            301.973
#
#         TOTAL_UNIT_AVG_WEEKLY_SALES                       REGION
# 0                             1.000           TOTAL AUTOS AREA 5
# ...

# %% [markdown]
# ## Limpeza de datos
# De acuerdo con lo recopilado, las siguientes tablas tendran Ciertas modificaciones:
#
# Product:
# - Eliminacion de Nulos
# - Eliminado de Duplciados (Item ya que es usado como identificador)
#
# Category:
# - Se renombrara la primera fila, debido que a la hora de cargar la informacion, esta tomo un nombre poco practico (FABRIC TREATMENT and SANIT\r\n)
#
# Calendar:
# - Normalizacion de las Fechas, ya que SALES maneja la columna week como "mes-año", mientras que CALENDAR lo maneja "semana - año"

# %% [markdown]
# #### PRODUCT

# %%
"""  DETECCION DE DUPLICADOS  """
print(df_product.duplicated(["ITEM"]).sum())
# Out:
# 1

# %%
"""  DETECCION DEL VALOR  """
df_product[df_product.duplicated(["ITEM"], keep=False)]
# Out:
#     MANUFACTURER     BRAND ITEM  \
# 502   INDS. ALEN  CLORALEX  NaN
# 503       CLOROX    CLOROX  NaN
#
#                                      ITEM_DESCRIPTION  ID_CATEGORY   FORMAT  \
# 502                CLORALEX EL RENDIDOR BOT PLAST 2LT            1  LIQUIDO
# 503  CLOROX MASCOTAS BLANQUEADOR+DETERGENTE GALON 10L            1  LIQUIDO
#
#      ATTR1  ATTR2        ATTR3
# 502  CLORO  CLORO  NO DEFINIDO
# 503  CLORO  CLORO     MASCOTAS

# %%
# Los valores como Nan, seran tomados como Nulos para mayor ptacticidad
# Por ende, ese sera nuestro siguiente paso
"""  ELIMINADO DE VALORES NULOS EN LA COLUMNA (ITEM)  """
df_pdt_clean = df_product.dropna()
df_pdt_clean.head(50)
# Out:
#                 MANUFACTURER               BRAND          ITEM  \
# 0                 INDS. ALEN            CLORALEX      75000592
# 1                 INDS. ALEN            CLORALEX      75000608
# 2                 INDS. ALEN            CLORALEX      75000615
# 3                 INDS. ALEN            CLORALEX      75000622
# 4                 INDS. ALEN            CLORALEX      75000639
# 5                 INDS. ALEN            CLORALEX      75000646
# 6                 INDS. ALEN            CLORALEX      75000653
# 7                 INDS. ALEN            CLORALEX      75000677
# 8                 INDS. ALEN            CLORALEX      75000684
# 9             QUIMICA GONCAL              PATITO      75010539
# 10                   RECKITT               LYSOL   19200958714
# 11                       P&G                TIDE   37000018704
# 12                       P&G                TIDE   37000213215
# 13                       P&G                TIDE   37000830870
# ...

# %% [markdown]
# #### CATEGORY

# %%
"""  MODIFICAICON DE PRIMERA FILA  """
#Esta línea modifica el valor de la celda que está en:
# Fila 0 (la primera fila del DataFrame)
# Columna 'CATEGORY'

df_category.loc[0, "CATEGORY"] = "FABRIC TREATMENT and SANIT"
df_category
# Out:
#    ID_CATEGORY                    CATEGORY
# 0            1  FABRIC TREATMENT and SANIT
# 1            2                   AIR CARE
# 2            3                LAVAVAJILLAS
# 3            4            MEGA SUPERFICIES
# 4            5         LAVATORY CARE & BRC

# %% [markdown]
# #### CALENDAR

# %%
"""  CREACION DE FUNCION DE NORMALIZAICON  """
def normalizar_week(valor):
    valor = str(valor).strip().lower()
    
    # Si ya está en formato semana-año
    if '-' in valor and valor.split('-')[0].isdigit():
        semana, año = valor.split('-')
        return f"{int(semana):02d}-{año}"
    
    # Si está en formato mes-año
    try:
        fecha = pd.to_datetime(valor, format='%b-%y', errors='coerce')
        if pd.isnull(fecha):
            fecha = pd.to_datetime(valor, format='%B-%y', errors='coerce')  # por si viene como "mes-año"
        if pd.notnull(fecha):
            semana = fecha.isocalendar().week
            año = fecha.year % 100  # para que coincida con "semana" en DF2
            return f"{semana:02d}-{año}"
    except:
        return np.nan

    return np.nan

# %%
# Aplicamos la funcion al DF
df_sales["WEEK"] = df_sales["WEEK"].apply(normalizar_week)

# %%
# Verificar coincidencias
coinciden = df_sales['WEEK'].isin(df_calendar['WEEK'])
print(f"Coincidencias: {coinciden.sum()} de {len(df_sales)}") # Total de coincidencias contra ValorTotal
# Out:
# Coincidencias: 109722 de 122002

# %%
"""
POR ULTIMO HAREMOS EL MERGE, ESTE PASO SE MOSTRARA EN OTRO SEGMENTE PARA 
LLEVAR UNA MEJOR ORGANIZACION DE LOS PAOS SEGUIDOS Y DE LA INFORMACION  
"""
# Out:
# '\nPOR ULTIMO HAREMOS EL MERGE, ESTE PASO SE MOSTRARA EN OTRO SEGMENTE PARA \nLLEVAR UNA MEJOR ORGANIZACION DE LOS PAOS SEGUIDOS Y DE LA INFORMACION  \n'

# %% [markdown]
# ## Union de los DataFrames
# Haremos Merge sobre los DF mas reeelevantes, esto nos ayudara a conciliar de mejor manera la informacion, de acuerdo a un maquetado realizado previamente, las relaciones quedarian de la siguiente forma:
# ![Tablas relacionales_250913_160018.jpg](attachment:722afba9-9fec-4bac-a6db-8f969e64bae0.jpg)

# %% [markdown]
# De forma explicada, quedaria de la siguiente forma
#
# -CATEGORY- se relacionara con SEGMENT y PRODUCT mediante "CATEGORY_ID" a "CATEGORY"
#
# -PRODUCT- se relacionara con SALES mediante "ITEM" A "ITEM_CODE"
#
# -SALES- se relacionara con CALENDAR mediante "WEEK" A "WEEK"

# %% [markdown]
# ### DF Para analisis de Productos por Categoria y/o Segmento
# (df_pdt)

# %%
"""  CREACION DE MERGE
este paso es un poco mas complicado de explicar, debido a que la relacion de SEGMENT y PRODUCT es mas especial, ya que se creara una 
columna en PRODUCT llamada SEGMENT
Para ello tendremos que validar que la informacion de estas 5 columnas, coincida en hambas tablas: 'CATEGORY', 'FORMAT', 'ATTR1', 'ATTR2', 'ATTR3'
Si conciden, se les asignara el valor de la Tabla Segemento a la nueva columna SEGMENT em PRODUCT

Esto nos dara nuestra primer seccion de DaraFrames
"""
# Out:
# "  CREACION DE MERGE\neste paso es un poco mas complicado de explicar, debido a que la relacion de SEGMENT y PRODUCT es mas especial, ya que se creara una \ncolumna en PRODUCT llamada SEGMENT\nPara ello tendremos que validar que la informacion de estas 5 columnas, coincida en hambas tablas: 'CATEGORY', 'FORMAT', 'ATTR1', 'ATTR2', 'ATTR3'\nSi conciden, se les asignara el valor de la Tabla Segemento a la nueva columna SEGMENT em PRODUCT\n\nEsto nos dara nuestra primer seccion de DaraFrames\n"

# %%
# Limpiamos las columnas
# Pasamos todo a mayusculas y sin espacios
cols = ['ID_CATEGORY', 'FORMAT', 'ATTR1', 'ATTR2', 'ATTR3']
for col in cols:
    df_segment[col] = df_segment[col].astype(str).str.strip().str.upper()
    df_pdt_clean[col] = df_pdt_clean[col].astype(str).str.strip().str.upper()
# Out:
# C:\Users\RyanHz\AppData\Local\Temp\ipykernel_6972\993188519.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pdt_clean[col] = df_pdt_clean[col].astype(str).str.strip().str.upper()
# C:\Users\RyanHz\AppData\Local\Temp\ipykernel_6972\993188519.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pdt_clean[col] = df_pdt_clean[col].astype(str).str.strip().str.upper()
# C:\Users\RyanHz\AppData\Local\Temp\ipykernel_6972\993188519.py:6: SettingWithCopyWarning:
# ...

# %%
df_pdt_clean = pd.merge(
    df_pdt_clean,
    df_segment[cols + ['SEGMENT']],  # solo las columnas necesarias
    on=cols,
    how='left'
)

# Renombrar la columna para que se llame SEGMENTO
df_pdt_clean.rename(columns={'SEGMENT': 'SEGMENTO'}, inplace=True)

df_pdt = df_pdt_clean.loc[:, ~df_pdt_clean.columns.duplicated()] # Borramos las columnas duplicadas de SEGMENTO
df_pdt
# Out:
#            MANUFACTURER      BRAND              ITEM  \
# 0            INDS. ALEN   CLORALEX          75000592
# 1            INDS. ALEN   CLORALEX          75000608
# 2            INDS. ALEN   CLORALEX          75000615
# 3            INDS. ALEN   CLORALEX          75000622
# 4            INDS. ALEN   CLORALEX          75000639
# ..                  ...        ...               ...
# 492              IBERIA     IBERIA     8411660210036
# 493  JABONERA LA ESPUMA  BCLORHADA  7501681101305BP1
# 494             RECKITT     VANISH  7501058789778BP1
# 495          INDS. ALEN   CLORALEX     7501025412142
# 496              CLOROX     CLOROX  7502240948188BP1
#
#                                       ITEM_DESCRIPTION ID_CATEGORY   FORMAT  \
# 0    CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 000...           1  LIQUIDO
# 1    CLORALEX EL RENDIDOR BOT.PLAST. 500ML NAL. 000...           1  LIQUIDO
# 2    CLORALEX EL RENDIDOR BOT.PLAST. 950ML NAL. 000...           1  LIQUIDO
# ...

# %%
# GUARDADO EN CSV Y EXCEL
df_pdt.to_csv("productos_por_cate.csv", index=False)
df_pdt.to_excel("productos_por_cate.xlsx", index=False)

# %% [markdown]
# ### DF Para analisis de Ventas
# (df_ventas)

# %%
df_ventas = pd.merge(df_sales, df_calendar, on = "WEEK", how="inner")
df_ventas
# Out:
#          WEEK              ITEM  TOTAL_UNIT_SALES  TOTAL_VALUE_SALES  \
# 0       34-22  7501058792808BP2             0.006              0.139
# 1       34-22     7501060000000             0.487            116.519
# 2       34-22     7702630000000             1.391             68.453
# 3       34-22     7501060000000             0.022              1.481
# 4       34-22     7501060000000             2.037            182.839
# ...       ...               ...               ...                ...
# 109717  26-23  7501058792778BP1             1.192            150.829
# 109718  26-23     7501060000000             1.947            235.416
# 109719  26-23     7501060000000            18.013            429.289
# 109720  26-23  7702626204208BP1            21.152            210.276
# 109721  26-23     7501060000000             1.468            301.973
#
#         TOTAL_UNIT_AVG_WEEKLY_SALES                       REGION  YEAR  MONTH  \
# ...

# %%
# GUARDADO EN CSV Y EXCEL
df_ventas.to_csv("venta.csv", index=False)
df_ventas.to_excel("ventas.xlsx", index=False)

# %% [markdown]
# ### DF Para analisis de Productos con ventas
# (df_ventas_x_pdt)

# %%
df_ventas_x_pdt = pd.merge(df_ventas, df_pdt, on="ITEM", how="inner")
df_ventas_x_pdt
# Out:
#        WEEK              ITEM  TOTAL_UNIT_SALES  TOTAL_VALUE_SALES  \
# 0     34-22  7501058792808BP2             0.006              0.139
# 1     34-22  7501058794963BP1             0.004              0.553
# 2     34-22  7501058792778BP1             0.001              0.128
# 3     34-22  7702626204208BP1             2.188             23.792
# 4     34-22       46500022692             0.024              2.040
# ...     ...               ...               ...                ...
# 9609  26-23  7501058794956BP2             0.015              0.336
# 9610  26-23  7501058796578BP1             0.359             19.816
# 9611  26-23  7501058792808BP2             1.232             25.128
# 9612  26-23  7501058792778BP1             1.192            150.829
# 9613  26-23  7702626204208BP1            21.152            210.276
#
#       TOTAL_UNIT_AVG_WEEKLY_SALES                       REGION  YEAR  MONTH  \
# 0                           1.000           TOTAL AUTOS AREA 5  2022      8
# ...

# %%
# GUARDADO EN CSV Y EXCEL
df_ventas_x_pdt.to_csv("ventas_por_producto.csv", index=False)
df_ventas_x_pdt.to_excel("ventas_por_producto.xlsx", index=False)
