# %%
import pandas as pd

df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
"""  Creacion de un stripplot  """
import seaborn as sns
sns.stripplot(data = df, y = "writing score", x = "math score", jitter = True)
# Out:
# <Axes: xlabel='math score', ylabel='writing score'>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
sns.stripplot(data= df, y="writing score", x="math score", jitter = True)
ax.axes.xaxis.set_ticks([])
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
sns.stripplot(data= df, y="writing score", x="race/ethnicity", jitter = True, hue="race/ethnicity", palette="Set2")
plt.show()

# %%
"""  Creacion de swarmplot  """
# Busca colocar loas observaciones de manera que no se empalmen
sns.swarmplot(data=df, y="writing score", x="race/ethnicity", hue="race/ethnicity", palette="Set2")
# Out:
# C:\Users\RyanHz\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\RyanHz\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>
# C:\Users\RyanHz\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\RyanHz\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
"""  Creacion de boxplot  """
sns.boxplot(data=df, y="writing score", x="race/ethnicity", hue="race/ethnicity", palette="Set2")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
"""  Creacion de violinplot  """
sns.violinplot(data=df, y="writing score", x="race/ethnicity", hue="race/ethnicity", palette="Set2")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
"""  Crecion de lvplot (LetterValuePlot)  """
# Conviene para bases de datos grandes
sns.catplot(data=df, y="writing score", x="race/ethnicity", kind="boxen", hue="race/ethnicity", palette="Set2")

# %%
"""  Creacion de barplot  """
sns.barplot(data=df, y="writing score", x="race/ethnicity", hue="race/ethnicity", palette="Set2")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
## Comparacion de grupos
sns.barplot(data=df, y="writing score", x="race/ethnicity", hue="lunch", palette="Set1")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
"""  Creacion de pointplot  """
sns.pointplot(data=df, y="writing score", x="race/ethnicity", hue="race/ethnicity", palette="Set2")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
sns.pointplot(data=df, y="writing score", x="race/ethnicity", hue="lunch", palette="Set1")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
"""  Creacion de countplot  """
sns.countplot(data=df, y="race/ethnicity", hue="lunch", palette="Set1")
# Out:
# <Axes: xlabel='count', ylabel='race/ethnicity'>

# %%
"""  Creacion de regplot (Grafico de regresion)  """
sns.regplot(data=df, y="writing score", x="reading score", marker = "+")
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
"""  Creacion de residuales  """
sns.residplot(data=df, y="writing score", x="reading score")
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
"""  Creacion de graficos con regresion con regplo y media por valor de x"""
# Util para enfatizar tendencias
import numpy as np
sns.regplot(data=df, y="writing score", x="reading score", x_estimator= np.mean)
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
"""  Creacion de heatmap (mapa de calor)  """
sns.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 2
#       1 """  Creacion de heatmap (mapa de calor)  """
# ----> 2 sns.heatmap(df.corr())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 sns.heatmap(df.corr(), annot = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...
